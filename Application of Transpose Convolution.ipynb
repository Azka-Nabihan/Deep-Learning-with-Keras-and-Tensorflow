# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, UpSampling2D
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Define The Input Layer

# %%
input_layer = Input(shape=(28, 28, 1))

# %% [markdown]
# creates an input layer with image size of 28x28 1 chanel (grayscale)

# %% [markdown]
# ## Add Convolutional and Transpose Convolutional Layer

# %%
# creates a convolution layer with 32 filters of size 3x3
conv_layer = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same')(input_layer)

# creates a transpose convolution layer for reconstructing the image
transpose_conv_layer = Conv2DTranspose(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same')(conv_layer)

# %% [markdown]
# ## Create the model

# %%
model = Model(inputs=input_layer, outputs=transpose_conv_layer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = Model(inputs=input_layer, outputs=transpose_conv_layer)
#
# NameError: name 'Model' is not defined
